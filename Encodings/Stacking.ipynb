# %% [markdown]
# # STACKING

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
import pickle as pkl
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Final Classifier Search

# %%
df = pkl.load(open("stacking_selection_experiments_avgfp/stacking_results.pkl", "rb"))

# %%
df
# Out:
#       Enc1                   Enc2                  Classifier Stacking  \
# 0   PAM250  Micheletti_potentials      LogisticRegression5000      clf
# 1   PAM250  Micheletti_potentials      LogisticRegression5000      clf
# 2   PAM250  Micheletti_potentials      LogisticRegression5000      clf
# 3   PAM250  Micheletti_potentials      LogisticRegression5000      clf
# 4   PAM250  Micheletti_potentials      LogisticRegression5000      clf
# ..     ...                    ...                         ...      ...
# 75  PAM250  Micheletti_potentials  RandomForestClassifier1000     mean
# 76  PAM250  Micheletti_potentials  RandomForestClassifier1000     mean
# 77  PAM250  Micheletti_potentials  RandomForestClassifier1000     mean
# 78  PAM250  Micheletti_potentials  RandomForestClassifier1000     mean
# 79  PAM250  Micheletti_potentials  RandomForestClassifier1000     mean
#
#          AUC
# 0   0.866029
# 1   0.862919
# 2   0.871973
# 3   0.878075
# 4   0.866502
# ..       ...
# ...

# %%
# Boxplot for folds aucs
sns.boxplot(x="Classifier", y="AUC", hue="Stacking", data=df, palette="Set1")
plt.title(f'AUC by final classifier | 5-fold CV', fontsize=14)
# Tilt x labels
plt.xticks(rotation=45);
